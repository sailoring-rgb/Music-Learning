# %% [markdown]
# # Music Generation with Deep Learning
#
# ### Music characteristics:
#
# * Pitch
# * Duration

# %% [markdown]
# ## Imports

# %%
# !pip3 install keras-visualizer
import sys, os, random, IPython, warnings, music21
from music21 import *
from IPython.display import Image, Audio
from collections import Counter
warnings.filterwarnings("ignore")
from keras_visualizer import visualizer 
warnings.simplefilter("ignore")
from music21 import note
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Concatenate
from tensorflow.keras.models import Model
import tensorflow as tf
import tensorflow 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adamax
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
np.random.seed(42)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-visualizer
#   Downloading keras_visualizer-3.1.2-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from keras-visualizer) (0.20.1)
# Installing collected packages: keras-visualizer
# Successfully installed keras-visualizer-3.1.2

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Get MIDI music files

# %%
cwd = os.getcwd()
fileHalsey = cwd + "/drive/MyDrive/input/Halsey_music"
fileBeethoven = cwd + "/drive/MyDrive/input/classical-music/beeth"
filepath = fileBeethoven

all_midis= []
for i in os.listdir(filepath):
    if i.endswith(".mid"):
        print(i)
        tr = filepath+"/"+i
        midi = converter.parse(tr)
        all_midis.append(midi)
# Out:
# beethoven_opus10_1.mid
# beethoven_opus10_2.mid
# beethoven_opus10_3.mid
# pathetique_1.mid
# pathetique_3.mid
# pathetique_2.mid
# beethoven_opus22_1.mid
# beethoven_opus22_2.mid
# beethoven_opus22_3.mid
# beethoven_opus22_4.mid
# mond_1.mid
# mond_2.mid
# mond_3.mid
# waldstein_1.mid
# waldstein_2.mid
# waldstein_3.mid
# appass_1.mid
# appass_2.mid
# appass_3.mid
# beethoven_les_adieux_1.mid
# beethoven_les_adieux_2.mid
# beethoven_les_adieux_3.mid
# beethoven_hammerklavier_1.mid
# beethoven_hammerklavier_2.mid
# beethoven_hammerklavier_3.mid
# beethoven_hammerklavier_4.mid
# elise.mid
# beethoven_opus90_1.mid
# beethoven_opus90_2.mid

# %% [markdown]
# ## Create Pich and Duration Corpus

# %%
def extract_notes(file):
    pitches = []
    durations = []
    pick = None
    for j in file:
        songs = instrument.partitionByInstrument(j)
        for part in songs.parts:
            pick = part.recurse()
            for element in pick:
                if isinstance(element, note.Note):
                    pitches.append(str(element.pitch))
                    durations.append(element.duration.quarterLength)
                elif isinstance(element, chord.Chord):
                    pitches.append(".".join(str(n) for n in element.normalOrder))
                    durations.append(element.duration.quarterLength)

    return pitches, durations

Corpus_pitches, Corpus_durations = extract_notes(all_midis)

# %% [markdown]
# ## Create Corpus's mapping and reverse mapping

# %%
symb_notes = sorted(list(set(Corpus_pitches))) 
symb_durations = sorted(list(set(Corpus_durations))) 

L_pitches = len(Corpus_pitches) 
L_durations = len(Corpus_durations)  
L_symb_notes = len(symb_notes) 
L_symb_durations = len(symb_durations) 

mapping_notes = dict((c, i) for i, c in enumerate(symb_notes))  
mapping_durations = dict((c, i) for i, c in enumerate(symb_durations))  
reverse_mapping_notes = dict((i, c) for i, c in enumerate(symb_notes)) 
reverse_mapping_durations = dict((i, c) for i, c in enumerate(symb_durations))

print("Total number of notes: ", L_pitches)
print("Number of unique notes: ", L_symb_notes)
print("Total number of durations: ", L_durations)
print("Number of unique durations: ", L_symb_durations)
# Out:
# Total number of notes:  81312
# Number of unique notes:  349
# Total number of durations:  81312
# Number of unique durations:  33

# %%
count_num = Counter(Corpus_pitches)

rare_note = []
for index, (key, value) in enumerate(count_num.items()):
    if value < 100:
        m =  key
        rare_note.append(m)
        
print("Total number of notes that occur less than 100 times: ", len(rare_note))

# %% [markdown]
# ### **Getting** a list of rare notes

# %%
rare_note = []
for index, (key, value) in enumerate(count_num.items()):
    if value < 100:
        m =  key
        rare_note.append(m)
        
print("Total number of notes that occur less than 100 times: ", len(rare_note))

# %% [markdown]
# ### **Eliminating** the rare notes

# %%
"""for element in Corpus_pitches:
    if element in rare_note:
        Corpus_pitches.remove(element)

print("Length of corpus after elemination the rare notes: ", len(Corpus_pitches))"""

# %% [markdown]
# ### **Replacing** the removed notes with the most frequent one

# %%
frequent_notes = []
for note, count in count_num.items():
    if count >= 100:
        frequent_notes.append(note)

for i in range(len(Corpus_pitches)):
    if Corpus_pitches[i] in rare_note:
        Corpus_pitches[i] = max(frequent_notes, key=lambda x: count_num[x])

print("Length of corpus after replacing the rare notes: ", len(Corpus_pitches))

# %% [markdown]
# ## Create Sequences to training model

# %%
length = 40
note_features = []
duration_features = []
note_targets = []
duration_targets = []
for i in range(0, L_pitches - length, 1):
    note_feature = Corpus_pitches[i:i + length]
    duration_feature = Corpus_durations[i:i + length]
    target_note = Corpus_pitches[i + length]
    target_duration = Corpus_durations[i + length]
    note_features.append([mapping_notes[j] for j in note_feature])
    duration_features.append([mapping_durations[k] for k in duration_feature])
    note_targets.append(mapping_notes[target_note])
    duration_targets.append(mapping_durations[target_duration])

L_datapoints = len(note_targets)
print("Total number of sequences in the corpus: ", L_datapoints)
# Out:
# Total number of sequences in the corpus:  81272

# %% [markdown]
# ## Reshape sequences for be in the format of model input

# %%
note_features = (np.reshape(note_features, (L_datapoints, length, 1))) / float(L_symb_notes)
duration_features = (np.reshape(duration_features, (L_datapoints, length, 1))) / float(L_symb_durations)
note_targets = tensorflow.keras.utils.to_categorical(note_targets)
duration_targets = tensorflow.keras.utils.to_categorical(duration_targets)

# %% [markdown]
# ## Split data into Training and Test

# %%
X_note_train, X_note_test, X_duration_train, X_duration_test, y_target_note_train, y_target_note_test, y_target_duration_train, y_target_duration_test = train_test_split(
    note_features, duration_features, note_targets, duration_targets, test_size=0.2, random_state=42
)

# %% [markdown]
# ## Build Model

# %%
note_input = Input(shape=(X_note_train.shape[1], X_note_train.shape[2]))
duration_input = Input(shape=(X_duration_train.shape[1], X_duration_train.shape[2]))

note_branch = LSTM(256, return_sequences=True)(note_input)
note_branch = Dropout(0.1)(note_branch)
note_branch = LSTM(128)(note_branch)

duration_branch = LSTM(256, return_sequences=True)(duration_input)
duration_branch = Dropout(0.1)(duration_branch)
duration_branch = LSTM(128)(duration_branch)

merged = Concatenate()([note_branch, duration_branch])
merged = Dense(128)(merged)
merged = Dropout(0.1)(merged)

output_note = Dense( y_target_note_train.shape[1], activation='softmax')(merged)
output_duration = Dense( y_target_duration_train.shape[1], activation='softmax')(merged)

model = Model(inputs=[note_input, duration_input], outputs=[output_note, output_duration])

opt = tf.keras.optimizers.Adamax(learning_rate=0.01)
model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy'],
              optimizer=opt,
              metrics=["accuracy"]),

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 40, 1)]      0           []
#
#  input_4 (InputLayer)           [(None, 40, 1)]      0           []
#
#  lstm_4 (LSTM)                  (None, 40, 256)      264192      ['input_3[0][0]']
#
#  lstm_6 (LSTM)                  (None, 40, 256)      264192      ['input_4[0][0]']
#
#  dropout_3 (Dropout)            (None, 40, 256)      0           ['lstm_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 40, 256)      0           ['lstm_6[0][0]']
#
#  lstm_5 (LSTM)                  (None, 128)          197120      ['dropout_3[0][0]']
#
#  lstm_7 (LSTM)                  (None, 128)          197120      ['dropout_4[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 256)          0           ['lstm_5[0][0]',
#                                                                   'lstm_7[0][0]']
#
#  dense_3 (Dense)                (None, 128)          32896       ['concatenate_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 349)          45021       ['dropout_5[0][0]']
#
#  dense_5 (Dense)                (None, 33)           4257        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 1,004,798
# Trainable params: 1,004,798
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train model

# %%
# BATCH_SIZE for Halsey is set for 128
# history = model.fit([X_note_train, X_duration_train], [y_target_note_train, y_target_duration_train], batch_size=128, epochs=150)
# BATCH_SIZE for Beethoven is set for 350
history = model.fit([X_note_train, X_duration_train], [y_target_note_train, y_target_duration_train], batch_size=350, epochs=150)
# Out:
# Epoch 1/150
# 186/186 [==============================] - 15s 41ms/step - loss: 6.0648 - dense_4_loss: 4.8141 - dense_5_loss: 1.2506 - dense_4_accuracy: 0.0220 - dense_5_accuracy: 0.6330
# Epoch 2/150
# 186/186 [==============================] - 8s 40ms/step - loss: 5.7404 - dense_4_loss: 4.6421 - dense_5_loss: 1.0983 - dense_4_accuracy: 0.0258 - dense_5_accuracy: 0.6690
# Epoch 3/150
# 186/186 [==============================] - 8s 41ms/step - loss: 5.6897 - dense_4_loss: 4.6189 - dense_5_loss: 1.0708 - dense_4_accuracy: 0.0273 - dense_5_accuracy: 0.6800
# Epoch 4/150
# 186/186 [==============================] - 8s 41ms/step - loss: 5.6273 - dense_4_loss: 4.5941 - dense_5_loss: 1.0332 - dense_4_accuracy: 0.0296 - dense_5_accuracy: 0.6921
# Epoch 5/150
# 186/186 [==============================] - 8s 43ms/step - loss: 5.5625 - dense_4_loss: 4.5765 - dense_5_loss: 0.9860 - dense_4_accuracy: 0.0313 - dense_5_accuracy: 0.7079
# Epoch 6/150
# 186/186 [==============================] - 8s 41ms/step - loss: 5.4973 - dense_4_loss: 4.5542 - dense_5_loss: 0.9430 - dense_4_accuracy: 0.0337 - dense_5_accuracy: 0.7207
# Epoch 7/150
# 186/186 [==============================] - 8s 41ms/step - loss: 5.4183 - dense_4_loss: 4.5175 - dense_5_loss: 0.9008 - dense_4_accuracy: 0.0369 - dense_5_accuracy: 0.7321
# Epoch 8/150
# 186/186 [==============================] - 8s 41ms/step - loss: 5.3375 - dense_4_loss: 4.4750 - dense_5_loss: 0.8625 - dense_4_accuracy: 0.0408 - dense_5_accuracy: 0.7419
# Epoch 9/150
# 186/186 [==============================] - 8s 41ms/step - loss: 5.2466 - dense_4_loss: 4.4158 - dense_5_loss: 0.8308 - dense_4_accuracy: 0.0473 - dense_5_accuracy: 0.7496
# Epoch 10/150
# 186/186 [==============================] - 8s 41ms/step - loss: 5.1620 - dense_4_loss: 4.3549 - dense_5_loss: 0.8071 - dense_4_accuracy: 0.0542 - dense_5_accuracy: 0.7567
# Epoch 11/150
# 186/186 [==============================] - 8s 40ms/step - loss: 5.0722 - dense_4_loss: 4.2893 - dense_5_loss: 0.7829 - dense_4_accuracy: 0.0618 - dense_5_accuracy: 0.7612
# Epoch 12/150
# 186/186 [==============================] - 8s 41ms/step - loss: 4.9689 - dense_4_loss: 4.2075 - dense_5_loss: 0.7614 - dense_4_accuracy: 0.0743 - dense_5_accuracy: 0.7664
# Epoch 13/150
# 186/186 [==============================] - 8s 41ms/step - loss: 4.8637 - dense_4_loss: 4.1237 - dense_5_loss: 0.7400 - dense_4_accuracy: 0.0847 - dense_5_accuracy: 0.7730
# Epoch 14/150
# 186/186 [==============================] - 8s 41ms/step - loss: 4.7575 - dense_4_loss: 4.0357 - dense_5_loss: 0.7218 - dense_4_accuracy: 0.0940 - dense_5_accuracy: 0.7784
# Epoch 15/150
# 186/186 [==============================] - 8s 41ms/step - loss: 4.6559 - dense_4_loss: 3.9492 - dense_5_loss: 0.7067 - dense_4_accuracy: 0.1076 - dense_5_accuracy: 0.7824
# Epoch 16/150
# 186/186 [==============================] - 8s 41ms/step - loss: 4.5510 - dense_4_loss: 3.8613 - dense_5_loss: 0.6897 - dense_4_accuracy: 0.1190 - dense_5_accuracy: 0.7882
# Epoch 17/150
# 186/186 [==============================] - 8s 41ms/step - loss: 4.4634 - dense_4_loss: 3.7905 - dense_5_loss: 0.6729 - dense_4_accuracy: 0.1292 - dense_5_accuracy: 0.7931
# Epoch 18/150
# 186/186 [==============================] - 8s 40ms/step - loss: 4.3725 - dense_4_loss: 3.7100 - dense_5_loss: 0.6625 - dense_4_accuracy: 0.1389 - dense_5_accuracy: 0.7963
# Epoch 19/150
# 186/186 [==============================] - 8s 41ms/step - loss: 4.2917 - dense_4_loss: 3.6422 - dense_5_loss: 0.6495 - dense_4_accuracy: 0.1473 - dense_5_accuracy: 0.7995
# Epoch 20/150
# 186/186 [==============================] - 8s 41ms/step - loss: 4.2090 - dense_4_loss: 3.5709 - dense_5_loss: 0.6381 - dense_4_accuracy: 0.1569 - dense_5_accuracy: 0.8032
# Epoch 21/150
# 186/186 [==============================] - 8s 42ms/step - loss: 4.1380 - dense_4_loss: 3.5105 - dense_5_loss: 0.6275 - dense_4_accuracy: 0.1668 - dense_5_accuracy: 0.8051
# Epoch 22/150
# 186/186 [==============================] - 8s 41ms/step - loss: 4.0577 - dense_4_loss: 3.4427 - dense_5_loss: 0.6150 - dense_4_accuracy: 0.1766 - dense_5_accuracy: 0.8091
# Epoch 23/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.9849 - dense_4_loss: 3.3800 - dense_5_loss: 0.6050 - dense_4_accuracy: 0.1860 - dense_5_accuracy: 0.8118
# Epoch 24/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.9140 - dense_4_loss: 3.3216 - dense_5_loss: 0.5924 - dense_4_accuracy: 0.1968 - dense_5_accuracy: 0.8155
# Epoch 25/150
# 186/186 [==============================] - 8s 40ms/step - loss: 3.8458 - dense_4_loss: 3.2632 - dense_5_loss: 0.5825 - dense_4_accuracy: 0.2051 - dense_5_accuracy: 0.8176
# Epoch 26/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.7807 - dense_4_loss: 3.2073 - dense_5_loss: 0.5734 - dense_4_accuracy: 0.2126 - dense_5_accuracy: 0.8208
# Epoch 27/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.7170 - dense_4_loss: 3.1546 - dense_5_loss: 0.5624 - dense_4_accuracy: 0.2209 - dense_5_accuracy: 0.8221
# Epoch 28/150
# 186/186 [==============================] - 8s 42ms/step - loss: 3.6579 - dense_4_loss: 3.1026 - dense_5_loss: 0.5553 - dense_4_accuracy: 0.2310 - dense_5_accuracy: 0.8246
# Epoch 29/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.5872 - dense_4_loss: 3.0428 - dense_5_loss: 0.5444 - dense_4_accuracy: 0.2392 - dense_5_accuracy: 0.8284
# Epoch 30/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.5445 - dense_4_loss: 3.0073 - dense_5_loss: 0.5372 - dense_4_accuracy: 0.2457 - dense_5_accuracy: 0.8302
# Epoch 31/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.4863 - dense_4_loss: 2.9578 - dense_5_loss: 0.5285 - dense_4_accuracy: 0.2549 - dense_5_accuracy: 0.8327
# Epoch 32/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.4316 - dense_4_loss: 2.9116 - dense_5_loss: 0.5200 - dense_4_accuracy: 0.2628 - dense_5_accuracy: 0.8344
# Epoch 33/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.3813 - dense_4_loss: 2.8669 - dense_5_loss: 0.5144 - dense_4_accuracy: 0.2709 - dense_5_accuracy: 0.8363
# Epoch 34/150
# 186/186 [==============================] - 8s 40ms/step - loss: 3.3368 - dense_4_loss: 2.8330 - dense_5_loss: 0.5038 - dense_4_accuracy: 0.2752 - dense_5_accuracy: 0.8393
# Epoch 35/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.2847 - dense_4_loss: 2.7911 - dense_5_loss: 0.4936 - dense_4_accuracy: 0.2842 - dense_5_accuracy: 0.8437
# Epoch 36/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.2426 - dense_4_loss: 2.7543 - dense_5_loss: 0.4884 - dense_4_accuracy: 0.2923 - dense_5_accuracy: 0.8447
# Epoch 37/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.1936 - dense_4_loss: 2.7125 - dense_5_loss: 0.4811 - dense_4_accuracy: 0.3004 - dense_5_accuracy: 0.8455
# Epoch 38/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.1595 - dense_4_loss: 2.6838 - dense_5_loss: 0.4757 - dense_4_accuracy: 0.3056 - dense_5_accuracy: 0.8476
# Epoch 39/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.1115 - dense_4_loss: 2.6447 - dense_5_loss: 0.4668 - dense_4_accuracy: 0.3106 - dense_5_accuracy: 0.8491
# Epoch 40/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.0694 - dense_4_loss: 2.6114 - dense_5_loss: 0.4580 - dense_4_accuracy: 0.3192 - dense_5_accuracy: 0.8533
# Epoch 41/150
# 186/186 [==============================] - 8s 40ms/step - loss: 3.0375 - dense_4_loss: 2.5864 - dense_5_loss: 0.4511 - dense_4_accuracy: 0.3252 - dense_5_accuracy: 0.8541
# Epoch 42/150
# 186/186 [==============================] - 8s 41ms/step - loss: 3.0014 - dense_4_loss: 2.5559 - dense_5_loss: 0.4455 - dense_4_accuracy: 0.3288 - dense_5_accuracy: 0.8570
# Epoch 43/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.9569 - dense_4_loss: 2.5169 - dense_5_loss: 0.4401 - dense_4_accuracy: 0.3388 - dense_5_accuracy: 0.8577
# Epoch 44/150
# 186/186 [==============================] - 8s 42ms/step - loss: 2.9265 - dense_4_loss: 2.4916 - dense_5_loss: 0.4349 - dense_4_accuracy: 0.3412 - dense_5_accuracy: 0.8599
# Epoch 45/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.8959 - dense_4_loss: 2.4663 - dense_5_loss: 0.4296 - dense_4_accuracy: 0.3474 - dense_5_accuracy: 0.8613
# Epoch 46/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.8582 - dense_4_loss: 2.4341 - dense_5_loss: 0.4242 - dense_4_accuracy: 0.3510 - dense_5_accuracy: 0.8627
# Epoch 47/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.8249 - dense_4_loss: 2.4075 - dense_5_loss: 0.4174 - dense_4_accuracy: 0.3595 - dense_5_accuracy: 0.8641
# Epoch 48/150
# 186/186 [==============================] - 8s 40ms/step - loss: 2.7907 - dense_4_loss: 2.3800 - dense_5_loss: 0.4107 - dense_4_accuracy: 0.3641 - dense_5_accuracy: 0.8670
# Epoch 49/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.7594 - dense_4_loss: 2.3538 - dense_5_loss: 0.4056 - dense_4_accuracy: 0.3691 - dense_5_accuracy: 0.8690
# Epoch 50/150
# 186/186 [==============================] - 8s 40ms/step - loss: 2.7308 - dense_4_loss: 2.3298 - dense_5_loss: 0.4010 - dense_4_accuracy: 0.3737 - dense_5_accuracy: 0.8689
# Epoch 51/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.6996 - dense_4_loss: 2.3059 - dense_5_loss: 0.3937 - dense_4_accuracy: 0.3784 - dense_5_accuracy: 0.8727
# Epoch 52/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.6613 - dense_4_loss: 2.2706 - dense_5_loss: 0.3907 - dense_4_accuracy: 0.3873 - dense_5_accuracy: 0.8735
# Epoch 53/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.6375 - dense_4_loss: 2.2557 - dense_5_loss: 0.3818 - dense_4_accuracy: 0.3901 - dense_5_accuracy: 0.8761
# Epoch 54/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.6150 - dense_4_loss: 2.2356 - dense_5_loss: 0.3794 - dense_4_accuracy: 0.3934 - dense_5_accuracy: 0.8761
# Epoch 55/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.5822 - dense_4_loss: 2.2105 - dense_5_loss: 0.3717 - dense_4_accuracy: 0.3998 - dense_5_accuracy: 0.8782
# Epoch 56/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.5481 - dense_4_loss: 2.1841 - dense_5_loss: 0.3640 - dense_4_accuracy: 0.4047 - dense_5_accuracy: 0.8810
# Epoch 57/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.5226 - dense_4_loss: 2.1607 - dense_5_loss: 0.3619 - dense_4_accuracy: 0.4093 - dense_5_accuracy: 0.8822
# Epoch 58/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.5076 - dense_4_loss: 2.1464 - dense_5_loss: 0.3612 - dense_4_accuracy: 0.4121 - dense_5_accuracy: 0.8818
# Epoch 59/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.4802 - dense_4_loss: 2.1267 - dense_5_loss: 0.3535 - dense_4_accuracy: 0.4195 - dense_5_accuracy: 0.8844
# Epoch 60/150
# 186/186 [==============================] - 8s 42ms/step - loss: 2.4573 - dense_4_loss: 2.1061 - dense_5_loss: 0.3512 - dense_4_accuracy: 0.4213 - dense_5_accuracy: 0.8846
# Epoch 61/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.4364 - dense_4_loss: 2.0901 - dense_5_loss: 0.3463 - dense_4_accuracy: 0.4236 - dense_5_accuracy: 0.8862
# Epoch 62/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.3989 - dense_4_loss: 2.0608 - dense_5_loss: 0.3381 - dense_4_accuracy: 0.4335 - dense_5_accuracy: 0.8888
# Epoch 63/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.3908 - dense_4_loss: 2.0522 - dense_5_loss: 0.3386 - dense_4_accuracy: 0.4357 - dense_5_accuracy: 0.8902
# Epoch 64/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.3528 - dense_4_loss: 2.0205 - dense_5_loss: 0.3323 - dense_4_accuracy: 0.4405 - dense_5_accuracy: 0.8917
# Epoch 65/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.3336 - dense_4_loss: 2.0061 - dense_5_loss: 0.3275 - dense_4_accuracy: 0.4454 - dense_5_accuracy: 0.8927
# Epoch 66/150
# 186/186 [==============================] - 8s 40ms/step - loss: 2.3090 - dense_4_loss: 1.9854 - dense_5_loss: 0.3235 - dense_4_accuracy: 0.4483 - dense_5_accuracy: 0.8936
# Epoch 67/150
# 186/186 [==============================] - 8s 42ms/step - loss: 2.3068 - dense_4_loss: 1.9825 - dense_5_loss: 0.3243 - dense_4_accuracy: 0.4501 - dense_5_accuracy: 0.8935
# Epoch 68/150
# 186/186 [==============================] - 8s 42ms/step - loss: 2.2757 - dense_4_loss: 1.9568 - dense_5_loss: 0.3190 - dense_4_accuracy: 0.4541 - dense_5_accuracy: 0.8954
# Epoch 69/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.2463 - dense_4_loss: 1.9341 - dense_5_loss: 0.3122 - dense_4_accuracy: 0.4595 - dense_5_accuracy: 0.8965
# Epoch 70/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.2212 - dense_4_loss: 1.9134 - dense_5_loss: 0.3079 - dense_4_accuracy: 0.4665 - dense_5_accuracy: 0.8981
# Epoch 71/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.2127 - dense_4_loss: 1.9067 - dense_5_loss: 0.3060 - dense_4_accuracy: 0.4656 - dense_5_accuracy: 0.8987
# Epoch 72/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.1930 - dense_4_loss: 1.8902 - dense_5_loss: 0.3028 - dense_4_accuracy: 0.4702 - dense_5_accuracy: 0.9002
# Epoch 73/150
# 186/186 [==============================] - 8s 40ms/step - loss: 2.1747 - dense_4_loss: 1.8768 - dense_5_loss: 0.2979 - dense_4_accuracy: 0.4743 - dense_5_accuracy: 0.9021
# Epoch 74/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.1604 - dense_4_loss: 1.8627 - dense_5_loss: 0.2977 - dense_4_accuracy: 0.4778 - dense_5_accuracy: 0.9010
# Epoch 75/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.1467 - dense_4_loss: 1.8497 - dense_5_loss: 0.2970 - dense_4_accuracy: 0.4798 - dense_5_accuracy: 0.9023
# Epoch 76/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.1232 - dense_4_loss: 1.8370 - dense_5_loss: 0.2861 - dense_4_accuracy: 0.4873 - dense_5_accuracy: 0.9060
# Epoch 77/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.1133 - dense_4_loss: 1.8236 - dense_5_loss: 0.2898 - dense_4_accuracy: 0.4860 - dense_5_accuracy: 0.9049
# Epoch 78/150
# 186/186 [==============================] - 8s 40ms/step - loss: 2.0948 - dense_4_loss: 1.8079 - dense_5_loss: 0.2869 - dense_4_accuracy: 0.4904 - dense_5_accuracy: 0.9063
# Epoch 79/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.0675 - dense_4_loss: 1.7861 - dense_5_loss: 0.2814 - dense_4_accuracy: 0.4951 - dense_5_accuracy: 0.9075
# Epoch 80/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.0611 - dense_4_loss: 1.7809 - dense_5_loss: 0.2801 - dense_4_accuracy: 0.4976 - dense_5_accuracy: 0.9074
# Epoch 81/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.0312 - dense_4_loss: 1.7554 - dense_5_loss: 0.2759 - dense_4_accuracy: 0.5031 - dense_5_accuracy: 0.9089
# Epoch 82/150
# 186/186 [==============================] - 8s 41ms/step - loss: 2.0221 - dense_4_loss: 1.7478 - dense_5_loss: 0.2743 - dense_4_accuracy: 0.5072 - dense_5_accuracy: 0.9097
# Epoch 83/150
# 186/186 [==============================] - 8s 42ms/step - loss: 2.0079 - dense_4_loss: 1.7392 - dense_5_loss: 0.2687 - dense_4_accuracy: 0.5058 - dense_5_accuracy: 0.9115
# Epoch 84/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.9940 - dense_4_loss: 1.7232 - dense_5_loss: 0.2708 - dense_4_accuracy: 0.5121 - dense_5_accuracy: 0.9107
# Epoch 85/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.9697 - dense_4_loss: 1.7043 - dense_5_loss: 0.2654 - dense_4_accuracy: 0.5132 - dense_5_accuracy: 0.9115
# Epoch 86/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.9660 - dense_4_loss: 1.6996 - dense_5_loss: 0.2664 - dense_4_accuracy: 0.5151 - dense_5_accuracy: 0.9125
# Epoch 87/150
# 186/186 [==============================] - 8s 40ms/step - loss: 1.9360 - dense_4_loss: 1.6781 - dense_5_loss: 0.2579 - dense_4_accuracy: 0.5236 - dense_5_accuracy: 0.9141
# Epoch 88/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.9290 - dense_4_loss: 1.6712 - dense_5_loss: 0.2578 - dense_4_accuracy: 0.5219 - dense_5_accuracy: 0.9146
# Epoch 89/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.9156 - dense_4_loss: 1.6632 - dense_5_loss: 0.2524 - dense_4_accuracy: 0.5266 - dense_5_accuracy: 0.9150
# Epoch 90/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.9034 - dense_4_loss: 1.6493 - dense_5_loss: 0.2541 - dense_4_accuracy: 0.5266 - dense_5_accuracy: 0.9153
# Epoch 91/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.8860 - dense_4_loss: 1.6360 - dense_5_loss: 0.2500 - dense_4_accuracy: 0.5306 - dense_5_accuracy: 0.9182
# Epoch 92/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.8835 - dense_4_loss: 1.6332 - dense_5_loss: 0.2504 - dense_4_accuracy: 0.5316 - dense_5_accuracy: 0.9171
# Epoch 93/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.8694 - dense_4_loss: 1.6192 - dense_5_loss: 0.2502 - dense_4_accuracy: 0.5358 - dense_5_accuracy: 0.9165
# Epoch 94/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.8439 - dense_4_loss: 1.6006 - dense_5_loss: 0.2433 - dense_4_accuracy: 0.5411 - dense_5_accuracy: 0.9187
# Epoch 95/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.8323 - dense_4_loss: 1.5872 - dense_5_loss: 0.2451 - dense_4_accuracy: 0.5459 - dense_5_accuracy: 0.9195
# Epoch 96/150
# 186/186 [==============================] - 8s 40ms/step - loss: 1.8282 - dense_4_loss: 1.5855 - dense_5_loss: 0.2427 - dense_4_accuracy: 0.5456 - dense_5_accuracy: 0.9201
# Epoch 97/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.8067 - dense_4_loss: 1.5690 - dense_5_loss: 0.2377 - dense_4_accuracy: 0.5493 - dense_5_accuracy: 0.9209
# Epoch 98/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.7994 - dense_4_loss: 1.5623 - dense_5_loss: 0.2371 - dense_4_accuracy: 0.5498 - dense_5_accuracy: 0.9219
# Epoch 99/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.7840 - dense_4_loss: 1.5483 - dense_5_loss: 0.2357 - dense_4_accuracy: 0.5545 - dense_5_accuracy: 0.9213
# Epoch 100/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.7773 - dense_4_loss: 1.5416 - dense_5_loss: 0.2357 - dense_4_accuracy: 0.5572 - dense_5_accuracy: 0.9208
# Epoch 101/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.7652 - dense_4_loss: 1.5308 - dense_5_loss: 0.2344 - dense_4_accuracy: 0.5542 - dense_5_accuracy: 0.9222
# Epoch 102/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.7532 - dense_4_loss: 1.5207 - dense_5_loss: 0.2325 - dense_4_accuracy: 0.5613 - dense_5_accuracy: 0.9237
# Epoch 103/150
# 186/186 [==============================] - 8s 40ms/step - loss: 1.7398 - dense_4_loss: 1.5091 - dense_5_loss: 0.2307 - dense_4_accuracy: 0.5650 - dense_5_accuracy: 0.9249
# Epoch 104/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.7231 - dense_4_loss: 1.4962 - dense_5_loss: 0.2269 - dense_4_accuracy: 0.5673 - dense_5_accuracy: 0.9254
# Epoch 105/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.7159 - dense_4_loss: 1.4908 - dense_5_loss: 0.2251 - dense_4_accuracy: 0.5674 - dense_5_accuracy: 0.9252
# Epoch 106/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.7160 - dense_4_loss: 1.4920 - dense_5_loss: 0.2240 - dense_4_accuracy: 0.5660 - dense_5_accuracy: 0.9261
# Epoch 107/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.7053 - dense_4_loss: 1.4823 - dense_5_loss: 0.2230 - dense_4_accuracy: 0.5714 - dense_5_accuracy: 0.9261
# Epoch 108/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.6868 - dense_4_loss: 1.4662 - dense_5_loss: 0.2206 - dense_4_accuracy: 0.5751 - dense_5_accuracy: 0.9274
# Epoch 109/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.6881 - dense_4_loss: 1.4666 - dense_5_loss: 0.2215 - dense_4_accuracy: 0.5742 - dense_5_accuracy: 0.9260
# Epoch 110/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.6697 - dense_4_loss: 1.4539 - dense_5_loss: 0.2159 - dense_4_accuracy: 0.5803 - dense_5_accuracy: 0.9294
# Epoch 111/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.6665 - dense_4_loss: 1.4513 - dense_5_loss: 0.2152 - dense_4_accuracy: 0.5772 - dense_5_accuracy: 0.9286
# Epoch 112/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.6468 - dense_4_loss: 1.4340 - dense_5_loss: 0.2127 - dense_4_accuracy: 0.5832 - dense_5_accuracy: 0.9300
# Epoch 113/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.6487 - dense_4_loss: 1.4352 - dense_5_loss: 0.2135 - dense_4_accuracy: 0.5814 - dense_5_accuracy: 0.9285
# Epoch 114/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.6195 - dense_4_loss: 1.4103 - dense_5_loss: 0.2091 - dense_4_accuracy: 0.5885 - dense_5_accuracy: 0.9306
# Epoch 115/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.6300 - dense_4_loss: 1.4192 - dense_5_loss: 0.2108 - dense_4_accuracy: 0.5862 - dense_5_accuracy: 0.9296
# Epoch 116/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.6199 - dense_4_loss: 1.4075 - dense_5_loss: 0.2124 - dense_4_accuracy: 0.5894 - dense_5_accuracy: 0.9300
# Epoch 117/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.6045 - dense_4_loss: 1.3979 - dense_5_loss: 0.2066 - dense_4_accuracy: 0.5934 - dense_5_accuracy: 0.9302
# Epoch 118/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5815 - dense_4_loss: 1.3774 - dense_5_loss: 0.2041 - dense_4_accuracy: 0.5997 - dense_5_accuracy: 0.9322
# Epoch 119/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5922 - dense_4_loss: 1.3845 - dense_5_loss: 0.2077 - dense_4_accuracy: 0.5951 - dense_5_accuracy: 0.9306
# Epoch 120/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5775 - dense_4_loss: 1.3760 - dense_5_loss: 0.2015 - dense_4_accuracy: 0.5999 - dense_5_accuracy: 0.9326
# Epoch 121/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5717 - dense_4_loss: 1.3646 - dense_5_loss: 0.2070 - dense_4_accuracy: 0.6013 - dense_5_accuracy: 0.9314
# Epoch 122/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5430 - dense_4_loss: 1.3496 - dense_5_loss: 0.1935 - dense_4_accuracy: 0.6060 - dense_5_accuracy: 0.9358
# Epoch 123/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.5573 - dense_4_loss: 1.3546 - dense_5_loss: 0.2027 - dense_4_accuracy: 0.6052 - dense_5_accuracy: 0.9316
# Epoch 124/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5418 - dense_4_loss: 1.3475 - dense_5_loss: 0.1943 - dense_4_accuracy: 0.6074 - dense_5_accuracy: 0.9362
# Epoch 125/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5264 - dense_4_loss: 1.3299 - dense_5_loss: 0.1965 - dense_4_accuracy: 0.6128 - dense_5_accuracy: 0.9354
# Epoch 126/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5267 - dense_4_loss: 1.3285 - dense_5_loss: 0.1982 - dense_4_accuracy: 0.6108 - dense_5_accuracy: 0.9340
# Epoch 127/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5154 - dense_4_loss: 1.3218 - dense_5_loss: 0.1935 - dense_4_accuracy: 0.6138 - dense_5_accuracy: 0.9363
# Epoch 128/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.5117 - dense_4_loss: 1.3177 - dense_5_loss: 0.1940 - dense_4_accuracy: 0.6130 - dense_5_accuracy: 0.9358
# Epoch 129/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4984 - dense_4_loss: 1.3048 - dense_5_loss: 0.1936 - dense_4_accuracy: 0.6185 - dense_5_accuracy: 0.9345
# Epoch 130/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.4890 - dense_4_loss: 1.2960 - dense_5_loss: 0.1930 - dense_4_accuracy: 0.6191 - dense_5_accuracy: 0.9358
# Epoch 131/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4902 - dense_4_loss: 1.3001 - dense_5_loss: 0.1901 - dense_4_accuracy: 0.6200 - dense_5_accuracy: 0.9364
# Epoch 132/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4780 - dense_4_loss: 1.2890 - dense_5_loss: 0.1890 - dense_4_accuracy: 0.6204 - dense_5_accuracy: 0.9374
# Epoch 133/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4749 - dense_4_loss: 1.2829 - dense_5_loss: 0.1920 - dense_4_accuracy: 0.6237 - dense_5_accuracy: 0.9361
# Epoch 134/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4624 - dense_4_loss: 1.2752 - dense_5_loss: 0.1872 - dense_4_accuracy: 0.6240 - dense_5_accuracy: 0.9377
# Epoch 135/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4491 - dense_4_loss: 1.2643 - dense_5_loss: 0.1848 - dense_4_accuracy: 0.6290 - dense_5_accuracy: 0.9377
# Epoch 136/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4539 - dense_4_loss: 1.2670 - dense_5_loss: 0.1870 - dense_4_accuracy: 0.6267 - dense_5_accuracy: 0.9376
# Epoch 137/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4427 - dense_4_loss: 1.2583 - dense_5_loss: 0.1844 - dense_4_accuracy: 0.6284 - dense_5_accuracy: 0.9389
# Epoch 138/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.4303 - dense_4_loss: 1.2479 - dense_5_loss: 0.1823 - dense_4_accuracy: 0.6321 - dense_5_accuracy: 0.9394
# Epoch 139/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4275 - dense_4_loss: 1.2467 - dense_5_loss: 0.1808 - dense_4_accuracy: 0.6318 - dense_5_accuracy: 0.9398
# Epoch 140/150
# 186/186 [==============================] - 8s 40ms/step - loss: 1.4147 - dense_4_loss: 1.2319 - dense_5_loss: 0.1828 - dense_4_accuracy: 0.6385 - dense_5_accuracy: 0.9399
# Epoch 141/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.4090 - dense_4_loss: 1.2290 - dense_5_loss: 0.1800 - dense_4_accuracy: 0.6394 - dense_5_accuracy: 0.9403
# Epoch 142/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.3974 - dense_4_loss: 1.2180 - dense_5_loss: 0.1794 - dense_4_accuracy: 0.6428 - dense_5_accuracy: 0.9403
# Epoch 143/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.3996 - dense_4_loss: 1.2210 - dense_5_loss: 0.1786 - dense_4_accuracy: 0.6394 - dense_5_accuracy: 0.9398
# Epoch 144/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.3928 - dense_4_loss: 1.2185 - dense_5_loss: 0.1742 - dense_4_accuracy: 0.6409 - dense_5_accuracy: 0.9427
# Epoch 145/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.3798 - dense_4_loss: 1.2045 - dense_5_loss: 0.1753 - dense_4_accuracy: 0.6439 - dense_5_accuracy: 0.9420
# Epoch 146/150
# 186/186 [==============================] - 8s 42ms/step - loss: 1.3523 - dense_4_loss: 1.1797 - dense_5_loss: 0.1726 - dense_4_accuracy: 0.6506 - dense_5_accuracy: 0.9426
# Epoch 147/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.3746 - dense_4_loss: 1.1985 - dense_5_loss: 0.1761 - dense_4_accuracy: 0.6468 - dense_5_accuracy: 0.9419
# Epoch 148/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.3631 - dense_4_loss: 1.1903 - dense_5_loss: 0.1728 - dense_4_accuracy: 0.6460 - dense_5_accuracy: 0.9415
# Epoch 149/150
# 186/186 [==============================] - 8s 40ms/step - loss: 1.3409 - dense_4_loss: 1.1732 - dense_5_loss: 0.1676 - dense_4_accuracy: 0.6535 - dense_5_accuracy: 0.9443
# Epoch 150/150
# 186/186 [==============================] - 8s 41ms/step - loss: 1.3540 - dense_4_loss: 1.1807 - dense_5_loss: 0.1733 - dense_4_accuracy: 0.6498 - dense_5_accuracy: 0.9420

# %%
history_df = pd.DataFrame(history.history)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(8, 8), facecolor="#97BACB")
fig.suptitle("Metrics: Loss & Accuracy")

# Plot Pitches Loss
# sns.lineplot(data=history_df["dense_1_loss"], color="#444160", ax=ax1)
sns.lineplot(data=history_df["dense_4_loss"], color="#444160", ax=ax1)
ax1.set_ylabel("Training Loss - Pitches")
ax1.set_xlabel("Epochs")

# Plot Duration Loss
# sns.lineplot(data=history_df["dense_2_loss"], color="#E96A48", ax=ax2)
sns.lineplot(data=history_df["dense_5_loss"], color="#E96A48", ax=ax2)
ax2.set_ylabel("Training Loss - Duration")
ax2.set_xlabel("Epochs")

# Plot Pitches Accuracy
# sns.lineplot(data=history_df["dense_1_accuracy"], color="#444160", ax=ax3)
sns.lineplot(data=history_df["dense_4_accuracy"], color="#444160", ax=ax3)
ax3.set_ylabel("Training Accuracy - Pitches")
ax3.set_xlabel("Epochs")

# Plot Duration Accuracy
# sns.lineplot(data=history_df["dense_2_accuracy"], color="#E96A48", ax=ax4)
sns.lineplot(data=history_df["dense_5_accuracy"], color="#E96A48", ax=ax4)
ax4.set_ylabel("Training Accuracy - Duration")
ax4.set_xlabel("Epochs")

plt.show()

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='/content/model_architecture.png', show_shapes=True, show_layer_names=True)

# %%
def chords_n_notes(Snippet_notes, Snippet_durations):
    Melody = []
    offset = 0
    for note_val, duration_val in zip(Snippet_notes, Snippet_durations):
        # in case it is a chord
        if ("." in note_val or note_val.isdigit()):
            chord_notes = note_val.split(".")
            notes = [] 
            for j in chord_notes:
                inst_note = int(j)
                note_snip = note.Note(inst_note)
                note_snip.duration = duration.Duration(duration_val)
                note_snip.duration.quarterLength = duration_val
                notes.append(note_snip)
            chord_snip = chord.Chord(notes)
            chord_snip.offset = offset
            Melody.append(chord_snip)
        # in case it is a note
        else: 
            note_snip = note.Note(note_val)
            note_snip.offset = offset
            note_snip.duration.quarterLength = duration_val
            Melody.append(note_snip)

        offset += duration_val

    Melody_midi = stream.Stream(Melody)   
    return Melody_midi

def Melody_Generator(Note_Count):
    seed_notes = X_note_test[np.random.randint(0, len(X_note_test) - 1)]
    seed_durations = X_duration_test[np.random.randint(0, len(X_duration_test) - 1)]
    Music = []
    Notes_Generated = []
    Durations_Generated = []
    
    for i in range(Note_Count):
        seed_notes_reshaped = seed_notes.reshape(1, length, 1)
        seed_durations_reshaped = seed_durations.reshape(1, length, 1)
        
        prediction_notes, prediction_durations = model.predict([seed_notes_reshaped, seed_durations_reshaped], verbose=0)
        
        # Convert predictions to probabilities
        prediction_notes = np.log(prediction_notes) / 1.0
        prediction_durations = np.log(prediction_durations) / 1.0
        
        exp_preds_notes = np.exp(prediction_notes)
        exp_preds_durations = np.exp(prediction_durations)
        
        prediction_notes = exp_preds_notes / np.sum(exp_preds_notes)
        prediction_durations = exp_preds_durations / np.sum(exp_preds_durations)
        
        index_note = np.argmax(prediction_notes)
        index_duration = np.argmax(prediction_durations)
        
        index_N_note = index_note / float(L_symb_notes)
        index_N_duration = index_duration / float(L_symb_durations)
        
        Notes_Generated.append(index_note)
        Durations_Generated.append(index_duration)
        
        Music_notes = [reverse_mapping_notes[char] for char in Notes_Generated]
        Music_durations = [reverse_mapping_durations[char] for char in Durations_Generated]
        
        Music = chords_n_notes(Music_notes, Music_durations)
        
        seed_notes = np.insert(seed_notes, len(seed_notes), index_N_note)
        seed_notes = seed_notes[1:]
        
        seed_durations = np.insert(seed_durations, len(seed_durations), index_N_duration)
        seed_durations = seed_durations[1:]
    
    Melody_midi = stream.Stream(Music)
    return Music_notes, Music_durations, Melody_midi


# Notes and durations created by the model
Music_notes, Music_durations, Melody = Melody_Generator(100)

# %%
cwd = os.getcwd()
filepath = cwd + "/drive/MyDrive/"
filename = 'beeth.h5'
model.save(filepath + filename)

# %%
cwd = os.getcwd()
filepath = cwd + "/drive/MyDrive/"
filename = 'Melody_Generated_Beeth_1.mid'
Melody.write('midi',filepath + filename)
# Out:
# '/content/drive/MyDrive/Melody_Generated_Beeth_1.mid'
