# %% [markdown]
# # Music Generation with Deep Learning
#
# ### Music characteristics:
#
# * Pitch
# * Duration

# %% [markdown]
# ## Imports

# %%
# !pip3 install keras-visualizer
import sys, os, random, IPython, warnings, music21
from music21 import *
from IPython.display import Image, Audio
from collections import Counter
warnings.filterwarnings("ignore")
from keras_visualizer import visualizer 
warnings.simplefilter("ignore")
from music21 import note
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Concatenate
from tensorflow.keras.models import Model
import tensorflow as tf
import tensorflow 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adamax
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
np.random.seed(42)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-visualizer
#   Downloading keras_visualizer-3.1.2-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from keras-visualizer) (0.20.1)
# Installing collected packages: keras-visualizer
# Successfully installed keras-visualizer-3.1.2

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Get MIDI music files

# %%
cwd = os.getcwd()
filepath = cwd + "/drive/MyDrive/Halsey-music"

all_midis= []
for i in os.listdir(filepath):
    if i.endswith(".mid"):
        print(i)
        tr = filepath+"/"+i
        midi = converter.parse(tr)
        all_midis.append(midi)
# Out:
# Colors.mid
# Gasoline.mid
# Closer.mid
# Sorry.mid
# So_Good.mid
# Him_I.mid
# Balenciaga.mid
# Tradition.mid
# Graveyard.mid
# You_Should_Be_Sad.mid
# Nightmare.mid
# New_Americana.mid
# Drive.mid
# 1121.mid
# I_Hate_Everybody.mid
# 11_Minutes.mid
# Is_There_Somewhere.mid
# 3am.mid
# Without_Me.mid
# More.mid
# Hold_Me_Down.mid
# Roman_Holiday.mid

# %% [markdown]
# ## Create Pich and Duration Corpus

# %%
def extract_notes(file):
    notes = []
    durations = []
    pick = None
    for j in file:
        songs = instrument.partitionByInstrument(j)
        for part in songs.parts:
            pick = part.recurse()
            for element in pick:
                if isinstance(element, note.Note):
                    notes.append(str(element.pitch))
                    durations.append(element.duration.quarterLength)
                elif isinstance(element, chord.Chord):
                    notes.append(".".join(str(n) for n in element.normalOrder))
                    durations.append(element.duration.quarterLength)

    return notes, durations

Corpus_notes, Corpus_durations = extract_notes(all_midis)
print(Corpus_durations)
# Out:
# [Fraction(2, 3), 0.75, 0.75, 0.5, 1.25, 1.25, 0.5, 1.0, 1.0, 0.25, 0.25, 0.25, Fraction(29, 12), Fraction(20, 3), 1.25, Fraction(2, 3), 1.75, 1.5, 0.5, 1.25, 2.0, Fraction(1, 3), Fraction(2, 3), Fraction(2, 3), Fraction(1, 3), 0.25, 0.5, Fraction(5, 12), 0.25, Fraction(4, 3), 0.75, 0.5, Fraction(2, 3), Fraction(1, 3), Fraction(2, 3), 1.0, 0.5, 0.5, 0.5, 1.25, 2.75, 2.5, 0.75, 1.25, Fraction(10, 3), Fraction(2, 3), 0.5, Fraction(2, 3), 1.5, 0.5, 1.5, Fraction(1, 3), Fraction(1, 3), Fraction(1, 3), 1.0, Fraction(7, 6), Fraction(1, 6), Fraction(25, 6), Fraction(1, 6), 1.0, Fraction(4, 3), 1.0, 1.0, 1.75, 1.25, Fraction(1, 3), 0.25, 0.5, Fraction(1, 3), Fraction(2, 3), 3.0, Fraction(2, 3), 1.25, 0.5, 0.25, 0.25, 1.0, 1.0, 1.0, 0.5, Fraction(1, 3), 0.5, 1.0, 0.75, 0.5, 2.25, 2.75, 0.25, 4.75, 0.5, 1.25, Fraction(8, 3), 1.5, 0.75, 1.0, Fraction(1, 3), 0.5, 1.25, Fraction(1, 3), 1.0, 0.25, 0.75, Fraction(2, 3), 1.0, 0.5, 0.5, Fraction(2, 3), 0.75, 0.5, 0.75, Fraction(1, 3), 1.25, Fraction(2, 3), Fraction(2, 3), Fraction(1, 3), Fraction(2, 3), Fraction(7, 3), Fraction(43, 12), 3.5, Fraction(1, 6), 0.5, 0.5, 1.0, Fraction(2, 3), 1.5, 0.5, 1.0, 0.75, 0.5, 0.5, Fraction(2, 3), 4.0, 1.0, 0.25, 1.25, 3.25, 0.25, 0.5, 1.0, 2.0, 0.25, Fraction(5, 12), 0.25, 0.5, 1.25, 1.25, 3.0, 1.25, Fraction(2, 3), 2.5, 1.25, Fraction(2, 3), 1.25, Fraction(1, 3), 0.5, Fraction(2, 3), 0.5, 1.0, 1.0, Fraction(1, 3), 6.0, 0.5, 0.75, 0.75, Fraction(2, 3), Fraction(1, 3), Fraction(1, 3), 1.5, Fraction(5, 3), 1.0, 1.25, Fraction(1, 3), 1.0, Fraction(4, 3), Fraction(7, 6), Fraction(2, 3), Fraction(2, 3), Fraction(5, 3), Fraction(2, 3), 0.75, 2.0, 1.25, 1.5, 0.5, 1.0, Fraction(1, 3), Fraction(1, 6), 1.5, Fraction(22, 3), 2.5, 1.25, Fraction(1, 3), 1.0, Fraction(5, 3), 0.5, 1.25, Fraction(2, 3), 1.75, Fraction(1, 3), 0.75, 1.25, 1.25, 1.25, Fraction(2, 3), 0.25, 1.0, 2.75, Fraction(5, 12), 1.25, Fraction(31, 12), 1.75, 1.5, 1.0, 0.5, 0.5, Fraction(1, 3), 0.5, Fraction(2, 3), 4.0, Fraction(1, 6), Fraction(1, 3), Fraction(4, 3), 0.5, 0.75, 1.25, 1.25, 1.75, 0.5, 1.0, 1.0, 0.5, 0.5, 1.0, 0.5, 0.25, 0.25, 0.75, 0.75, 1.25, 0.75, 0.75, 0.25, Fraction(1, 3), 0.75, 1.25, 0.5, Fraction(1, 3), Fraction(1, 3), 1.25, Fraction(1, 3), Fraction(2, 3), 0.5, 0.5, 1.0, Fraction(1, 3), Fraction(1, 3), 1.5, Fraction(2, 3), Fraction(2, 3), 1.25, Fraction(7, 3), 0.5, 1.25, Fraction(5, 3), 0.5, 1.0, 0.5, 0.5, Fraction(2, 3), 1.5, 2.0, Fraction(5, 3), Fraction(11, 6), Fraction(7, 6), 0.5, Fraction(2, 3), Fraction(2, 3), 0.75, 1.25, 2.0, Fraction(2, 3), 1.0, 1.0, Fraction(1, 3), 0.25, Fraction(5, 12), 2.5, 2.0, Fraction(7, 3), Fraction(2, 3), 0.25, 0.25, Fraction(1, 3), 1.25, 1.25, 1.25, 0.25, Fraction(13, 12), 4.25, 1.25, 1.0, 1.0, 0.5, 0.25, 0.5, 0.5, 1.25, 1.75, 3.5, Fraction(2, 3), 0.5, 1.75, Fraction(1, 3), 0.75, Fraction(5, 3), Fraction(2, 3), 0.75, Fraction(1, 3), Fraction(1, 6), 0.5, 0.5, 3.75, 1.0, 0.75, Fraction(1, 3), 1.0, 0.5, 1.25, Fraction(5, 3), 0.5, 1.75, Fraction(1, 3), 0.5, Fraction(2, 3), Fraction(2, 3), 1.0, Fraction(11, 12), Fraction(1, 3), Fraction(7, 12), Fraction(2, 3), 0.5, 1.0, Fraction(7, 3), Fraction(1, 3), Fraction(7, 3), 0.75, Fraction(2, 3), Fraction(2, 3), 1.0, 0.5, 0.5, 0.5, 0.5, 1.25, Fraction(2, 3), 0.25, Fraction(2, 3), 0.75, Fraction(11, 6), Fraction(1, 3), 1.25, 1.75, 0.5, 0.5, 1.25, Fraction(2, 3), 1.25, Fraction(1, 3), 1.0, Fraction(1, 3), Fraction(1, 3), 0.25, 0.25, Fraction(11, 12), Fraction(23, 12), 1.5, 0.5, Fraction(4, 3), 0.5, 1.5, 0.75, 0.5, 0.5, 1.0, Fraction(2, 3), Fraction(5, 3), Fraction(4, 3), 0.5, 2.5, Fraction(2, 3), 1.75, 1.0, Fraction(2, 3), 1.25, 0.5, Fraction(1, 3), 0.5, 0.5, 1.25, 0.75, 1.75, Fraction(7, 3), Fraction(1, 3), Fraction(5, 3), 0.75, Fraction(1, 3), 0.5, 1.0, Fraction(2, 3), Fraction(1, 3), 0.25, Fraction(7, 6), Fraction(2, 3), 0.5, 3.0, Fraction(2, 3), 1.75, 1.0, 0.25, Fraction(4, 3), 1.75, 0.5, Fraction(1, 3), 1.25, 0.5, 0.5, 2.0, Fraction(1, 3), 1.25, Fraction(2, 3), 0.5, Fraction(5, 3), 1.25, Fraction(1, 3), 0.75,  ...

# %% [markdown]
# ## Create Corpus's mapping and reverse mapping

# %%
symb_notes = sorted(list(set(Corpus_notes))) 
symb_durations = sorted(list(set(Corpus_durations))) 

L_notes = len(Corpus_notes) 
L_durations = len(Corpus_durations)  
L_symb_notes = len(symb_notes) 
L_symb_durations = len(symb_durations) 

mapping_notes = dict((c, i) for i, c in enumerate(symb_notes))  
mapping_durations = dict((c, i) for i, c in enumerate(symb_durations))  
reverse_mapping_notes = dict((i, c) for i, c in enumerate(symb_notes)) 
reverse_mapping_durations = dict((i, c) for i, c in enumerate(symb_durations))

print("Total number of notes: ", L_notes)
print("Number of unique notes: ", L_symb_notes)
print("Total number of durations: ", L_durations)
print("Number of unique durations: ", L_symb_durations)
# Out:
# Total number of notes:  25515
# Number of unique notes:  259
# Total number of durations:  25515
# Number of unique durations:  75

# %% [markdown]
# ## Create Sequences to training model

# %%
length = 40
note_features = []
duration_features = []
note_targets = []
duration_targets = []
for i in range(0, L_notes - length, 1):
    note_feature = Corpus_notes[i:i + length]
    duration_feature = Corpus_durations[i:i + length]
    target_note = Corpus_notes[i + length]
    target_duration = Corpus_durations[i + length]
    note_features.append([mapping_notes[j] for j in note_feature])
    duration_features.append([mapping_durations[k] for k in duration_feature])
    note_targets.append(mapping_notes[target_note])
    duration_targets.append(mapping_durations[target_duration])

L_datapoints = len(note_targets)
print("Total number of sequences in the corpus: ", L_datapoints)
# Out:
# Total number of sequences in the corpus:  25475

# %% [markdown]
# ## Reshape sequences for be in the format of model input

# %%
note_features = (np.reshape(note_features, (L_datapoints, length, 1))) / float(L_symb_notes)
duration_features = (np.reshape(duration_features, (L_datapoints, length, 1))) / float(L_symb_durations)
note_targets = tensorflow.keras.utils.to_categorical(note_targets)
duration_targets = tensorflow.keras.utils.to_categorical(duration_targets)

# %% [markdown]
# ## Split data into Training and Test

# %%
X_note_train, X_note_test, X_duration_train, X_duration_test, y_target_note_train, y_target_note_test, y_target_duration_train, y_target_duration_test = train_test_split(
    note_features, duration_features, note_targets, duration_targets, test_size=0.2, random_state=41
)

# %% [markdown]
# ## Build Model

# %%
note_input = Input(shape=(X_note_train.shape[1], X_note_train.shape[2]))
duration_input = Input(shape=(X_duration_train.shape[1], X_duration_train.shape[2]))

note_branch = LSTM(256, return_sequences=True)(note_input)
note_branch = Dropout(0.1)(note_branch)
note_branch = LSTM(128)(note_branch)

duration_branch = LSTM(256, return_sequences=True)(duration_input)
duration_branch = Dropout(0.1)(duration_branch)
duration_branch = LSTM(128)(duration_branch)

merged = Concatenate()([note_branch, duration_branch])
merged = Dense(128)(merged)
merged = Dropout(0.1)(merged)

output_note = Dense( y_target_note_train.shape[1], activation='softmax')(merged)
output_duration = Dense( y_target_duration_train.shape[1], activation='softmax')(merged)

model = Model(inputs=[note_input, duration_input], outputs=[output_note, output_duration])

opt = tf.keras.optimizers.Adamax(learning_rate=0.01)
model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy'],
              optimizer=opt,
              metrics=["accuracy"]),

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 40, 1)]      0           []
#
#  input_2 (InputLayer)           [(None, 40, 1)]      0           []
#
#  lstm (LSTM)                    (None, 40, 256)      264192      ['input_1[0][0]']
#
#  lstm_2 (LSTM)                  (None, 40, 256)      264192      ['input_2[0][0]']
#
#  dropout (Dropout)              (None, 40, 256)      0           ['lstm[0][0]']
#
#  dropout_1 (Dropout)            (None, 40, 256)      0           ['lstm_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 128)          197120      ['dropout[0][0]']
#
#  lstm_3 (LSTM)                  (None, 128)          197120      ['dropout_1[0][0]']
#
#  concatenate (Concatenate)      (None, 256)          0           ['lstm_1[0][0]',
#                                                                   'lstm_3[0][0]']
#
#  dense (Dense)                  (None, 128)          32896       ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 259)          33411       ['dropout_2[0][0]']
#
#  dense_2 (Dense)                (None, 75)           9675        ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 998,606
# Trainable params: 998,606
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train model

# %%
history = model.fit([X_note_train, X_duration_train], [y_target_note_train, y_target_duration_train], batch_size=128, epochs=150)
# Out:
# Epoch 1/150
# 160/160 [==============================] - 17s 22ms/step - loss: 7.4548 - dense_1_loss: 4.6377 - dense_2_loss: 2.8172 - dense_1_accuracy: 0.0391 - dense_2_accuracy: 0.1555
# Epoch 2/150
# 160/160 [==============================] - 3s 20ms/step - loss: 7.3250 - dense_1_loss: 4.5651 - dense_2_loss: 2.7599 - dense_1_accuracy: 0.0435 - dense_2_accuracy: 0.1601
# Epoch 3/150
# 160/160 [==============================] - 3s 20ms/step - loss: 7.2784 - dense_1_loss: 4.5378 - dense_2_loss: 2.7406 - dense_1_accuracy: 0.0421 - dense_2_accuracy: 0.1676
# Epoch 4/150
# 160/160 [==============================] - 3s 20ms/step - loss: 7.2395 - dense_1_loss: 4.5099 - dense_2_loss: 2.7297 - dense_1_accuracy: 0.0434 - dense_2_accuracy: 0.1687
# Epoch 5/150
# 160/160 [==============================] - 3s 22ms/step - loss: 7.1972 - dense_1_loss: 4.4772 - dense_2_loss: 2.7200 - dense_1_accuracy: 0.0430 - dense_2_accuracy: 0.1667
# Epoch 6/150
# 160/160 [==============================] - 3s 21ms/step - loss: 7.1635 - dense_1_loss: 4.4498 - dense_2_loss: 2.7137 - dense_1_accuracy: 0.0460 - dense_2_accuracy: 0.1695
# Epoch 7/150
# 160/160 [==============================] - 3s 20ms/step - loss: 7.1044 - dense_1_loss: 4.4021 - dense_2_loss: 2.7023 - dense_1_accuracy: 0.0479 - dense_2_accuracy: 0.1715
# Epoch 8/150
# 160/160 [==============================] - 3s 20ms/step - loss: 7.0535 - dense_1_loss: 4.3566 - dense_2_loss: 2.6968 - dense_1_accuracy: 0.0539 - dense_2_accuracy: 0.1761
# Epoch 9/150
# 160/160 [==============================] - 3s 22ms/step - loss: 7.0065 - dense_1_loss: 4.3188 - dense_2_loss: 2.6877 - dense_1_accuracy: 0.0582 - dense_2_accuracy: 0.1779
# Epoch 10/150
# 160/160 [==============================] - 3s 21ms/step - loss: 6.9482 - dense_1_loss: 4.2679 - dense_2_loss: 2.6803 - dense_1_accuracy: 0.0594 - dense_2_accuracy: 0.1785
# Epoch 11/150
# 160/160 [==============================] - 3s 22ms/step - loss: 6.8839 - dense_1_loss: 4.2177 - dense_2_loss: 2.6662 - dense_1_accuracy: 0.0680 - dense_2_accuracy: 0.1828
# Epoch 12/150
# 160/160 [==============================] - 3s 21ms/step - loss: 6.8094 - dense_1_loss: 4.1527 - dense_2_loss: 2.6567 - dense_1_accuracy: 0.0731 - dense_2_accuracy: 0.1857
# Epoch 13/150
# 160/160 [==============================] - 3s 22ms/step - loss: 6.7227 - dense_1_loss: 4.0807 - dense_2_loss: 2.6419 - dense_1_accuracy: 0.0797 - dense_2_accuracy: 0.1908
# Epoch 14/150
# 160/160 [==============================] - 4s 26ms/step - loss: 6.6356 - dense_1_loss: 4.0056 - dense_2_loss: 2.6300 - dense_1_accuracy: 0.0889 - dense_2_accuracy: 0.1893
# Epoch 15/150
# 160/160 [==============================] - 3s 21ms/step - loss: 6.5343 - dense_1_loss: 3.9199 - dense_2_loss: 2.6145 - dense_1_accuracy: 0.0961 - dense_2_accuracy: 0.1935
# Epoch 16/150
# 160/160 [==============================] - 3s 20ms/step - loss: 6.4119 - dense_1_loss: 3.8124 - dense_2_loss: 2.5995 - dense_1_accuracy: 0.1105 - dense_2_accuracy: 0.1961
# Epoch 17/150
# 160/160 [==============================] - 3s 22ms/step - loss: 6.3094 - dense_1_loss: 3.7242 - dense_2_loss: 2.5853 - dense_1_accuracy: 0.1190 - dense_2_accuracy: 0.2016
# Epoch 18/150
# 160/160 [==============================] - 3s 21ms/step - loss: 6.1798 - dense_1_loss: 3.6104 - dense_2_loss: 2.5694 - dense_1_accuracy: 0.1316 - dense_2_accuracy: 0.2072
# Epoch 19/150
# 160/160 [==============================] - 3s 20ms/step - loss: 6.0720 - dense_1_loss: 3.5203 - dense_2_loss: 2.5517 - dense_1_accuracy: 0.1445 - dense_2_accuracy: 0.2073
# Epoch 20/150
# 160/160 [==============================] - 3s 20ms/step - loss: 5.9570 - dense_1_loss: 3.4210 - dense_2_loss: 2.5359 - dense_1_accuracy: 0.1555 - dense_2_accuracy: 0.2091
# Epoch 21/150
# 160/160 [==============================] - 4s 22ms/step - loss: 5.8554 - dense_1_loss: 3.3330 - dense_2_loss: 2.5225 - dense_1_accuracy: 0.1715 - dense_2_accuracy: 0.2154
# Epoch 22/150
# 160/160 [==============================] - 3s 21ms/step - loss: 5.7552 - dense_1_loss: 3.2500 - dense_2_loss: 2.5052 - dense_1_accuracy: 0.1805 - dense_2_accuracy: 0.2179
# Epoch 23/150
# 160/160 [==============================] - 3s 20ms/step - loss: 5.6566 - dense_1_loss: 3.1660 - dense_2_loss: 2.4905 - dense_1_accuracy: 0.1913 - dense_2_accuracy: 0.2175
# Epoch 24/150
# 160/160 [==============================] - 3s 21ms/step - loss: 5.5548 - dense_1_loss: 3.0860 - dense_2_loss: 2.4688 - dense_1_accuracy: 0.2018 - dense_2_accuracy: 0.2251
# Epoch 25/150
# 160/160 [==============================] - 3s 22ms/step - loss: 5.4816 - dense_1_loss: 3.0242 - dense_2_loss: 2.4575 - dense_1_accuracy: 0.2138 - dense_2_accuracy: 0.2289
# Epoch 26/150
# 160/160 [==============================] - 3s 21ms/step - loss: 5.3827 - dense_1_loss: 2.9421 - dense_2_loss: 2.4406 - dense_1_accuracy: 0.2249 - dense_2_accuracy: 0.2274
# Epoch 27/150
# 160/160 [==============================] - 3s 21ms/step - loss: 5.3279 - dense_1_loss: 2.9021 - dense_2_loss: 2.4258 - dense_1_accuracy: 0.2321 - dense_2_accuracy: 0.2358
# Epoch 28/150
# 160/160 [==============================] - 3s 21ms/step - loss: 5.2372 - dense_1_loss: 2.8266 - dense_2_loss: 2.4106 - dense_1_accuracy: 0.2414 - dense_2_accuracy: 0.2385
# Epoch 29/150
# 160/160 [==============================] - 5s 29ms/step - loss: 5.1611 - dense_1_loss: 2.7662 - dense_2_loss: 2.3949 - dense_1_accuracy: 0.2521 - dense_2_accuracy: 0.2424
# Epoch 30/150
# 160/160 [==============================] - 3s 21ms/step - loss: 5.0846 - dense_1_loss: 2.7093 - dense_2_loss: 2.3753 - dense_1_accuracy: 0.2629 - dense_2_accuracy: 0.2424
# Epoch 31/150
# 160/160 [==============================] - 3s 20ms/step - loss: 5.0372 - dense_1_loss: 2.6725 - dense_2_loss: 2.3647 - dense_1_accuracy: 0.2702 - dense_2_accuracy: 0.2501
# Epoch 32/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.9660 - dense_1_loss: 2.6109 - dense_2_loss: 2.3551 - dense_1_accuracy: 0.2819 - dense_2_accuracy: 0.2547
# Epoch 33/150
# 160/160 [==============================] - 4s 22ms/step - loss: 4.8933 - dense_1_loss: 2.5651 - dense_2_loss: 2.3282 - dense_1_accuracy: 0.2914 - dense_2_accuracy: 0.2572
# Epoch 34/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.8249 - dense_1_loss: 2.5121 - dense_2_loss: 2.3127 - dense_1_accuracy: 0.3001 - dense_2_accuracy: 0.2621
# Epoch 35/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.7661 - dense_1_loss: 2.4705 - dense_2_loss: 2.2956 - dense_1_accuracy: 0.3063 - dense_2_accuracy: 0.2654
# Epoch 36/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.7330 - dense_1_loss: 2.4481 - dense_2_loss: 2.2850 - dense_1_accuracy: 0.3138 - dense_2_accuracy: 0.2686
# Epoch 37/150
# 160/160 [==============================] - 3s 22ms/step - loss: 4.6681 - dense_1_loss: 2.3953 - dense_2_loss: 2.2729 - dense_1_accuracy: 0.3206 - dense_2_accuracy: 0.2725
# Epoch 38/150
# 160/160 [==============================] - 3s 22ms/step - loss: 4.6072 - dense_1_loss: 2.3507 - dense_2_loss: 2.2565 - dense_1_accuracy: 0.3307 - dense_2_accuracy: 0.2714
# Epoch 39/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.5474 - dense_1_loss: 2.3109 - dense_2_loss: 2.2365 - dense_1_accuracy: 0.3392 - dense_2_accuracy: 0.2811
# Epoch 40/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.5046 - dense_1_loss: 2.2746 - dense_2_loss: 2.2300 - dense_1_accuracy: 0.3453 - dense_2_accuracy: 0.2819
# Epoch 41/150
# 160/160 [==============================] - 4s 23ms/step - loss: 4.4350 - dense_1_loss: 2.2272 - dense_2_loss: 2.2078 - dense_1_accuracy: 0.3540 - dense_2_accuracy: 0.2858
# Epoch 42/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.3875 - dense_1_loss: 2.1946 - dense_2_loss: 2.1929 - dense_1_accuracy: 0.3668 - dense_2_accuracy: 0.2906
# Epoch 43/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.3433 - dense_1_loss: 2.1622 - dense_2_loss: 2.1811 - dense_1_accuracy: 0.3719 - dense_2_accuracy: 0.2969
# Epoch 44/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.2818 - dense_1_loss: 2.1210 - dense_2_loss: 2.1608 - dense_1_accuracy: 0.3864 - dense_2_accuracy: 0.2977
# Epoch 45/150
# 160/160 [==============================] - 4s 23ms/step - loss: 4.2382 - dense_1_loss: 2.0937 - dense_2_loss: 2.1445 - dense_1_accuracy: 0.3855 - dense_2_accuracy: 0.3041
# Epoch 46/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.2029 - dense_1_loss: 2.0632 - dense_2_loss: 2.1397 - dense_1_accuracy: 0.3936 - dense_2_accuracy: 0.3069
# Epoch 47/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.1642 - dense_1_loss: 2.0408 - dense_2_loss: 2.1234 - dense_1_accuracy: 0.3967 - dense_2_accuracy: 0.3098
# Epoch 48/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.1104 - dense_1_loss: 1.9989 - dense_2_loss: 2.1115 - dense_1_accuracy: 0.4101 - dense_2_accuracy: 0.3121
# Epoch 49/150
# 160/160 [==============================] - 4s 24ms/step - loss: 4.0541 - dense_1_loss: 1.9675 - dense_2_loss: 2.0866 - dense_1_accuracy: 0.4184 - dense_2_accuracy: 0.3185
# Epoch 50/150
# 160/160 [==============================] - 3s 21ms/step - loss: 4.0339 - dense_1_loss: 1.9546 - dense_2_loss: 2.0793 - dense_1_accuracy: 0.4196 - dense_2_accuracy: 0.3252
# Epoch 51/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.9924 - dense_1_loss: 1.9217 - dense_2_loss: 2.0708 - dense_1_accuracy: 0.4252 - dense_2_accuracy: 0.3205
# Epoch 52/150
# 160/160 [==============================] - 3s 22ms/step - loss: 3.9183 - dense_1_loss: 1.8765 - dense_2_loss: 2.0419 - dense_1_accuracy: 0.4442 - dense_2_accuracy: 0.3346
# Epoch 53/150
# 160/160 [==============================] - 4s 23ms/step - loss: 3.8994 - dense_1_loss: 1.8716 - dense_2_loss: 2.0278 - dense_1_accuracy: 0.4412 - dense_2_accuracy: 0.3362
# Epoch 54/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.8619 - dense_1_loss: 1.8378 - dense_2_loss: 2.0242 - dense_1_accuracy: 0.4513 - dense_2_accuracy: 0.3332
# Epoch 55/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.8238 - dense_1_loss: 1.8183 - dense_2_loss: 2.0055 - dense_1_accuracy: 0.4538 - dense_2_accuracy: 0.3418
# Epoch 56/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.7669 - dense_1_loss: 1.7759 - dense_2_loss: 1.9910 - dense_1_accuracy: 0.4657 - dense_2_accuracy: 0.3464
# Epoch 57/150
# 160/160 [==============================] - 4s 23ms/step - loss: 3.7249 - dense_1_loss: 1.7476 - dense_2_loss: 1.9774 - dense_1_accuracy: 0.4725 - dense_2_accuracy: 0.3509
# Epoch 58/150
# 160/160 [==============================] - 3s 22ms/step - loss: 3.6880 - dense_1_loss: 1.7341 - dense_2_loss: 1.9539 - dense_1_accuracy: 0.4762 - dense_2_accuracy: 0.3556
# Epoch 59/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.6598 - dense_1_loss: 1.7087 - dense_2_loss: 1.9511 - dense_1_accuracy: 0.4793 - dense_2_accuracy: 0.3529
# Epoch 60/150
# 160/160 [==============================] - 3s 22ms/step - loss: 3.6074 - dense_1_loss: 1.6801 - dense_2_loss: 1.9273 - dense_1_accuracy: 0.4880 - dense_2_accuracy: 0.3635
# Epoch 61/150
# 160/160 [==============================] - 4s 23ms/step - loss: 3.5832 - dense_1_loss: 1.6625 - dense_2_loss: 1.9207 - dense_1_accuracy: 0.4930 - dense_2_accuracy: 0.3648
# Epoch 62/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.5438 - dense_1_loss: 1.6359 - dense_2_loss: 1.9080 - dense_1_accuracy: 0.5044 - dense_2_accuracy: 0.3683
# Epoch 63/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.4912 - dense_1_loss: 1.6030 - dense_2_loss: 1.8883 - dense_1_accuracy: 0.5090 - dense_2_accuracy: 0.3732
# Epoch 64/150
# 160/160 [==============================] - 4s 22ms/step - loss: 3.4594 - dense_1_loss: 1.5854 - dense_2_loss: 1.8740 - dense_1_accuracy: 0.5120 - dense_2_accuracy: 0.3814
# Epoch 65/150
# 160/160 [==============================] - 4s 23ms/step - loss: 3.4180 - dense_1_loss: 1.5628 - dense_2_loss: 1.8552 - dense_1_accuracy: 0.5201 - dense_2_accuracy: 0.3868
# Epoch 66/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.3748 - dense_1_loss: 1.5347 - dense_2_loss: 1.8401 - dense_1_accuracy: 0.5263 - dense_2_accuracy: 0.3886
# Epoch 67/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.3252 - dense_1_loss: 1.5053 - dense_2_loss: 1.8199 - dense_1_accuracy: 0.5397 - dense_2_accuracy: 0.3924
# Epoch 68/150
# 160/160 [==============================] - 4s 22ms/step - loss: 3.3088 - dense_1_loss: 1.4934 - dense_2_loss: 1.8154 - dense_1_accuracy: 0.5376 - dense_2_accuracy: 0.3988
# Epoch 69/150
# 160/160 [==============================] - 4s 22ms/step - loss: 3.2388 - dense_1_loss: 1.4541 - dense_2_loss: 1.7847 - dense_1_accuracy: 0.5482 - dense_2_accuracy: 0.4047
# Epoch 70/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.2134 - dense_1_loss: 1.4361 - dense_2_loss: 1.7773 - dense_1_accuracy: 0.5531 - dense_2_accuracy: 0.4054
# Epoch 71/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.1951 - dense_1_loss: 1.4282 - dense_2_loss: 1.7669 - dense_1_accuracy: 0.5561 - dense_2_accuracy: 0.4120
# Epoch 72/150
# 160/160 [==============================] - 4s 22ms/step - loss: 3.1470 - dense_1_loss: 1.3983 - dense_2_loss: 1.7487 - dense_1_accuracy: 0.5646 - dense_2_accuracy: 0.4140
# Epoch 73/150
# 160/160 [==============================] - 4s 22ms/step - loss: 3.1249 - dense_1_loss: 1.3911 - dense_2_loss: 1.7338 - dense_1_accuracy: 0.5676 - dense_2_accuracy: 0.4194
# Epoch 74/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.0746 - dense_1_loss: 1.3599 - dense_2_loss: 1.7148 - dense_1_accuracy: 0.5776 - dense_2_accuracy: 0.4238
# Epoch 75/150
# 160/160 [==============================] - 3s 21ms/step - loss: 3.0484 - dense_1_loss: 1.3496 - dense_2_loss: 1.6988 - dense_1_accuracy: 0.5776 - dense_2_accuracy: 0.4263
# Epoch 76/150
# 160/160 [==============================] - 4s 23ms/step - loss: 3.0128 - dense_1_loss: 1.3275 - dense_2_loss: 1.6853 - dense_1_accuracy: 0.5847 - dense_2_accuracy: 0.4359
# Epoch 77/150
# 160/160 [==============================] - 4s 22ms/step - loss: 2.9699 - dense_1_loss: 1.2966 - dense_2_loss: 1.6733 - dense_1_accuracy: 0.5982 - dense_2_accuracy: 0.4366
# Epoch 78/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.9662 - dense_1_loss: 1.3013 - dense_2_loss: 1.6648 - dense_1_accuracy: 0.5918 - dense_2_accuracy: 0.4404
# Epoch 79/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.9104 - dense_1_loss: 1.2676 - dense_2_loss: 1.6428 - dense_1_accuracy: 0.6043 - dense_2_accuracy: 0.4499
# Epoch 80/150
# 160/160 [==============================] - 4s 22ms/step - loss: 2.8781 - dense_1_loss: 1.2506 - dense_2_loss: 1.6276 - dense_1_accuracy: 0.6064 - dense_2_accuracy: 0.4497
# Epoch 81/150
# 160/160 [==============================] - 4s 22ms/step - loss: 2.8227 - dense_1_loss: 1.2190 - dense_2_loss: 1.6038 - dense_1_accuracy: 0.6142 - dense_2_accuracy: 0.4631
# Epoch 82/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.7844 - dense_1_loss: 1.1925 - dense_2_loss: 1.5919 - dense_1_accuracy: 0.6251 - dense_2_accuracy: 0.4661
# Epoch 83/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.7547 - dense_1_loss: 1.1793 - dense_2_loss: 1.5754 - dense_1_accuracy: 0.6258 - dense_2_accuracy: 0.4687
# Epoch 84/150
# 160/160 [==============================] - 4s 23ms/step - loss: 2.7118 - dense_1_loss: 1.1603 - dense_2_loss: 1.5516 - dense_1_accuracy: 0.6344 - dense_2_accuracy: 0.4778
# Epoch 85/150
# 160/160 [==============================] - 3s 22ms/step - loss: 2.6701 - dense_1_loss: 1.1414 - dense_2_loss: 1.5286 - dense_1_accuracy: 0.6385 - dense_2_accuracy: 0.4810
# Epoch 86/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.6741 - dense_1_loss: 1.1488 - dense_2_loss: 1.5253 - dense_1_accuracy: 0.6386 - dense_2_accuracy: 0.4836
# Epoch 87/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.6623 - dense_1_loss: 1.1370 - dense_2_loss: 1.5253 - dense_1_accuracy: 0.6408 - dense_2_accuracy: 0.4803
# Epoch 88/150
# 160/160 [==============================] - 4s 23ms/step - loss: 2.5719 - dense_1_loss: 1.0866 - dense_2_loss: 1.4853 - dense_1_accuracy: 0.6527 - dense_2_accuracy: 0.5004
# Epoch 89/150
# 160/160 [==============================] - 3s 22ms/step - loss: 2.5427 - dense_1_loss: 1.0730 - dense_2_loss: 1.4697 - dense_1_accuracy: 0.6620 - dense_2_accuracy: 0.5036
# Epoch 90/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.5045 - dense_1_loss: 1.0587 - dense_2_loss: 1.4458 - dense_1_accuracy: 0.6666 - dense_2_accuracy: 0.5114
# Epoch 91/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.4780 - dense_1_loss: 1.0458 - dense_2_loss: 1.4323 - dense_1_accuracy: 0.6654 - dense_2_accuracy: 0.5102
# Epoch 92/150
# 160/160 [==============================] - 4s 23ms/step - loss: 2.4581 - dense_1_loss: 1.0375 - dense_2_loss: 1.4206 - dense_1_accuracy: 0.6656 - dense_2_accuracy: 0.5145
# Epoch 93/150
# 160/160 [==============================] - 3s 22ms/step - loss: 2.4592 - dense_1_loss: 1.0370 - dense_2_loss: 1.4221 - dense_1_accuracy: 0.6683 - dense_2_accuracy: 0.5151
# Epoch 94/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.4206 - dense_1_loss: 1.0240 - dense_2_loss: 1.3965 - dense_1_accuracy: 0.6747 - dense_2_accuracy: 0.5238
# Epoch 95/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.3856 - dense_1_loss: 0.9990 - dense_2_loss: 1.3867 - dense_1_accuracy: 0.6809 - dense_2_accuracy: 0.5302
# Epoch 96/150
# 160/160 [==============================] - 4s 23ms/step - loss: 2.3208 - dense_1_loss: 0.9715 - dense_2_loss: 1.3493 - dense_1_accuracy: 0.6905 - dense_2_accuracy: 0.5405
# Epoch 97/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.3249 - dense_1_loss: 0.9665 - dense_2_loss: 1.3584 - dense_1_accuracy: 0.6874 - dense_2_accuracy: 0.5342
# Epoch 98/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.2967 - dense_1_loss: 0.9676 - dense_2_loss: 1.3291 - dense_1_accuracy: 0.6890 - dense_2_accuracy: 0.5449
# Epoch 99/150
# 160/160 [==============================] - 3s 22ms/step - loss: 2.2761 - dense_1_loss: 0.9615 - dense_2_loss: 1.3146 - dense_1_accuracy: 0.6930 - dense_2_accuracy: 0.5541
# Epoch 100/150
# 160/160 [==============================] - 4s 23ms/step - loss: 2.2575 - dense_1_loss: 0.9423 - dense_2_loss: 1.3152 - dense_1_accuracy: 0.6970 - dense_2_accuracy: 0.5476
# Epoch 101/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.2229 - dense_1_loss: 0.9360 - dense_2_loss: 1.2869 - dense_1_accuracy: 0.6986 - dense_2_accuracy: 0.5558
# Epoch 102/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.1884 - dense_1_loss: 0.9207 - dense_2_loss: 1.2677 - dense_1_accuracy: 0.7086 - dense_2_accuracy: 0.5660
# Epoch 103/150
# 160/160 [==============================] - 3s 22ms/step - loss: 2.1619 - dense_1_loss: 0.9040 - dense_2_loss: 1.2580 - dense_1_accuracy: 0.7094 - dense_2_accuracy: 0.5720
# Epoch 104/150
# 160/160 [==============================] - 4s 23ms/step - loss: 2.0972 - dense_1_loss: 0.8773 - dense_2_loss: 1.2200 - dense_1_accuracy: 0.7178 - dense_2_accuracy: 0.5810
# Epoch 105/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.0964 - dense_1_loss: 0.8830 - dense_2_loss: 1.2134 - dense_1_accuracy: 0.7156 - dense_2_accuracy: 0.5860
# Epoch 106/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.1012 - dense_1_loss: 0.8850 - dense_2_loss: 1.2162 - dense_1_accuracy: 0.7163 - dense_2_accuracy: 0.5839
# Epoch 107/150
# 160/160 [==============================] - 3s 22ms/step - loss: 2.0575 - dense_1_loss: 0.8677 - dense_2_loss: 1.1898 - dense_1_accuracy: 0.7243 - dense_2_accuracy: 0.5909
# Epoch 108/150
# 160/160 [==============================] - 4s 23ms/step - loss: 2.0400 - dense_1_loss: 0.8587 - dense_2_loss: 1.1813 - dense_1_accuracy: 0.7235 - dense_2_accuracy: 0.5990
# Epoch 109/150
# 160/160 [==============================] - 3s 21ms/step - loss: 2.0156 - dense_1_loss: 0.8612 - dense_2_loss: 1.1544 - dense_1_accuracy: 0.7204 - dense_2_accuracy: 0.6053
# Epoch 110/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.9547 - dense_1_loss: 0.8222 - dense_2_loss: 1.1325 - dense_1_accuracy: 0.7353 - dense_2_accuracy: 0.6104
# Epoch 111/150
# 160/160 [==============================] - 4s 22ms/step - loss: 1.9729 - dense_1_loss: 0.8292 - dense_2_loss: 1.1437 - dense_1_accuracy: 0.7345 - dense_2_accuracy: 0.6099
# Epoch 112/150
# 160/160 [==============================] - 4s 22ms/step - loss: 1.9335 - dense_1_loss: 0.8271 - dense_2_loss: 1.1064 - dense_1_accuracy: 0.7358 - dense_2_accuracy: 0.6195
# Epoch 113/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.8826 - dense_1_loss: 0.8024 - dense_2_loss: 1.0802 - dense_1_accuracy: 0.7419 - dense_2_accuracy: 0.6282
# Epoch 114/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.8795 - dense_1_loss: 0.7977 - dense_2_loss: 1.0818 - dense_1_accuracy: 0.7396 - dense_2_accuracy: 0.6254
# Epoch 115/150
# 160/160 [==============================] - 4s 22ms/step - loss: 1.8783 - dense_1_loss: 0.8018 - dense_2_loss: 1.0764 - dense_1_accuracy: 0.7409 - dense_2_accuracy: 0.6277
# Epoch 116/150
# 160/160 [==============================] - 4s 23ms/step - loss: 1.8369 - dense_1_loss: 0.7888 - dense_2_loss: 1.0481 - dense_1_accuracy: 0.7434 - dense_2_accuracy: 0.6383
# Epoch 117/150
# 160/160 [==============================] - 3s 22ms/step - loss: 1.7934 - dense_1_loss: 0.7676 - dense_2_loss: 1.0257 - dense_1_accuracy: 0.7510 - dense_2_accuracy: 0.6487
# Epoch 118/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.7697 - dense_1_loss: 0.7621 - dense_2_loss: 1.0076 - dense_1_accuracy: 0.7555 - dense_2_accuracy: 0.6554
# Epoch 119/150
# 160/160 [==============================] - 4s 22ms/step - loss: 1.7240 - dense_1_loss: 0.7366 - dense_2_loss: 0.9874 - dense_1_accuracy: 0.7603 - dense_2_accuracy: 0.6596
# Epoch 120/150
# 160/160 [==============================] - 4s 22ms/step - loss: 1.7649 - dense_1_loss: 0.7753 - dense_2_loss: 0.9897 - dense_1_accuracy: 0.7464 - dense_2_accuracy: 0.6599
# Epoch 121/150
# 160/160 [==============================] - 3s 22ms/step - loss: 1.7306 - dense_1_loss: 0.7521 - dense_2_loss: 0.9785 - dense_1_accuracy: 0.7553 - dense_2_accuracy: 0.6602
# Epoch 122/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.6699 - dense_1_loss: 0.7256 - dense_2_loss: 0.9443 - dense_1_accuracy: 0.7659 - dense_2_accuracy: 0.6745
# Epoch 123/150
# 160/160 [==============================] - 4s 23ms/step - loss: 1.6907 - dense_1_loss: 0.7387 - dense_2_loss: 0.9520 - dense_1_accuracy: 0.7620 - dense_2_accuracy: 0.6736
# Epoch 124/150
# 160/160 [==============================] - 4s 22ms/step - loss: 1.6564 - dense_1_loss: 0.7110 - dense_2_loss: 0.9454 - dense_1_accuracy: 0.7665 - dense_2_accuracy: 0.6720
# Epoch 125/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.6523 - dense_1_loss: 0.7252 - dense_2_loss: 0.9271 - dense_1_accuracy: 0.7674 - dense_2_accuracy: 0.6782
# Epoch 126/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.6364 - dense_1_loss: 0.7170 - dense_2_loss: 0.9193 - dense_1_accuracy: 0.7653 - dense_2_accuracy: 0.6849
# Epoch 127/150
# 160/160 [==============================] - 4s 23ms/step - loss: 1.5961 - dense_1_loss: 0.6997 - dense_2_loss: 0.8964 - dense_1_accuracy: 0.7724 - dense_2_accuracy: 0.6890
# Epoch 128/150
# 160/160 [==============================] - 3s 22ms/step - loss: 1.5715 - dense_1_loss: 0.6957 - dense_2_loss: 0.8758 - dense_1_accuracy: 0.7721 - dense_2_accuracy: 0.6965
# Epoch 129/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.5548 - dense_1_loss: 0.6817 - dense_2_loss: 0.8731 - dense_1_accuracy: 0.7813 - dense_2_accuracy: 0.6979
# Epoch 130/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.5081 - dense_1_loss: 0.6653 - dense_2_loss: 0.8428 - dense_1_accuracy: 0.7839 - dense_2_accuracy: 0.7088
# Epoch 131/150
# 160/160 [==============================] - 4s 23ms/step - loss: 1.5366 - dense_1_loss: 0.6858 - dense_2_loss: 0.8507 - dense_1_accuracy: 0.7787 - dense_2_accuracy: 0.7066
# Epoch 132/150
# 160/160 [==============================] - 3s 22ms/step - loss: 1.5176 - dense_1_loss: 0.6786 - dense_2_loss: 0.8391 - dense_1_accuracy: 0.7775 - dense_2_accuracy: 0.7099
# Epoch 133/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.4857 - dense_1_loss: 0.6612 - dense_2_loss: 0.8245 - dense_1_accuracy: 0.7883 - dense_2_accuracy: 0.7156
# Epoch 134/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.4818 - dense_1_loss: 0.6706 - dense_2_loss: 0.8112 - dense_1_accuracy: 0.7837 - dense_2_accuracy: 0.7211
# Epoch 135/150
# 160/160 [==============================] - 4s 23ms/step - loss: 1.4471 - dense_1_loss: 0.6538 - dense_2_loss: 0.7933 - dense_1_accuracy: 0.7854 - dense_2_accuracy: 0.7242
# Epoch 136/150
# 160/160 [==============================] - 3s 22ms/step - loss: 1.4089 - dense_1_loss: 0.6326 - dense_2_loss: 0.7763 - dense_1_accuracy: 0.7951 - dense_2_accuracy: 0.7285
# Epoch 137/150
# 160/160 [==============================] - 3s 22ms/step - loss: 1.4009 - dense_1_loss: 0.6247 - dense_2_loss: 0.7762 - dense_1_accuracy: 0.7980 - dense_2_accuracy: 0.7276
# Epoch 138/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.3771 - dense_1_loss: 0.6327 - dense_2_loss: 0.7444 - dense_1_accuracy: 0.7917 - dense_2_accuracy: 0.7405
# Epoch 139/150
# 160/160 [==============================] - 4s 23ms/step - loss: 1.3464 - dense_1_loss: 0.6138 - dense_2_loss: 0.7326 - dense_1_accuracy: 0.8009 - dense_2_accuracy: 0.7468
# Epoch 140/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.3573 - dense_1_loss: 0.6265 - dense_2_loss: 0.7308 - dense_1_accuracy: 0.7983 - dense_2_accuracy: 0.7483
# Epoch 141/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.3423 - dense_1_loss: 0.6172 - dense_2_loss: 0.7251 - dense_1_accuracy: 0.8001 - dense_2_accuracy: 0.7497
# Epoch 142/150
# 160/160 [==============================] - 3s 22ms/step - loss: 1.2790 - dense_1_loss: 0.5673 - dense_2_loss: 0.7117 - dense_1_accuracy: 0.8131 - dense_2_accuracy: 0.7579
# Epoch 143/150
# 160/160 [==============================] - 4s 23ms/step - loss: 1.3123 - dense_1_loss: 0.6072 - dense_2_loss: 0.7051 - dense_1_accuracy: 0.8018 - dense_2_accuracy: 0.7515
# Epoch 144/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.2853 - dense_1_loss: 0.5957 - dense_2_loss: 0.6897 - dense_1_accuracy: 0.8065 - dense_2_accuracy: 0.7628
# Epoch 145/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.2860 - dense_1_loss: 0.5982 - dense_2_loss: 0.6878 - dense_1_accuracy: 0.8040 - dense_2_accuracy: 0.7612
# Epoch 146/150
# 160/160 [==============================] - 3s 22ms/step - loss: 1.2603 - dense_1_loss: 0.5823 - dense_2_loss: 0.6780 - dense_1_accuracy: 0.8089 - dense_2_accuracy: 0.7638
# Epoch 147/150
# 160/160 [==============================] - 4s 22ms/step - loss: 1.2731 - dense_1_loss: 0.5924 - dense_2_loss: 0.6806 - dense_1_accuracy: 0.8067 - dense_2_accuracy: 0.7667
# Epoch 148/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.2646 - dense_1_loss: 0.5912 - dense_2_loss: 0.6734 - dense_1_accuracy: 0.8066 - dense_2_accuracy: 0.7647
# Epoch 149/150
# 160/160 [==============================] - 3s 21ms/step - loss: 1.2222 - dense_1_loss: 0.5684 - dense_2_loss: 0.6538 - dense_1_accuracy: 0.8130 - dense_2_accuracy: 0.7731
# Epoch 150/150
# 160/160 [==============================] - 4s 22ms/step - loss: 1.1936 - dense_1_loss: 0.5592 - dense_2_loss: 0.6344 - dense_1_accuracy: 0.8178 - dense_2_accuracy: 0.7809

# %%
history_df = pd.DataFrame(history.history)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(8, 8), facecolor="#97BACB")
fig.suptitle("Learning plot of model for loss and accuracy")

# Plot Loss
sns.lineplot(data=history_df["dense_1_loss"], color="#444160", ax=ax1)
ax1.set_ylabel("Training Loss - Notes")
ax1.set_xlabel("Epochs")

# Plot Accuracy
sns.lineplot(data=history_df["dense_2_loss"], color="#E96A48", ax=ax2)
ax2.set_ylabel("Training Loss - Duration")
ax2.set_xlabel("Epochs")

# Plot Loss
sns.lineplot(data=history_df["dense_1_accuracy"], color="#444160", ax=ax3)
ax3.set_ylabel("Training Accuracy - Notes")
ax3.set_xlabel("Epochs")

# Plot Accuracy
sns.lineplot(data=history_df["dense_2_accuracy"], color="#E96A48", ax=ax4)
ax4.set_ylabel("Training Accuracy - Duration")
ax4.set_xlabel("Epochs")

plt.show()

# %%
def chords_n_notes(Snippet_notes, Snippet_durations):
    Melody = []
    offset = 0
    for note_val, duration_val in zip(Snippet_notes, Snippet_durations):
        # in case it is a chord
        if ("." in note_val or note_val.isdigit()):
            chord_notes = note_val.split(".")
            notes = [] 
            for j in chord_notes:
                inst_note = int(j)
                note_snip = note.Note(inst_note)
                note_snip.duration = duration.Duration(duration_val)
                note_snip.duration.quarterLength = duration_val
                notes.append(note_snip)
            chord_snip = chord.Chord(notes)
            chord_snip.offset = offset
            Melody.append(chord_snip)
        # in case it is a note
        else: 
            note_snip = note.Note(note_val)
            note_snip.offset = offset
            note_snip.duration.quarterLength = duration_val
            Melody.append(note_snip)

        offset += duration_val

    Melody_midi = stream.Stream(Melody)   
    return Melody_midi

def Melody_Generator(Note_Count):
    seed_notes = X_note_test[np.random.randint(0, len(X_note_test) - 1)]
    seed_durations = X_duration_test[np.random.randint(0, len(X_duration_test) - 1)]
    Music = []
    Notes_Generated = []
    Durations_Generated = []
    
    for i in range(Note_Count):
        seed_notes_reshaped = seed_notes.reshape(1, length, 1)
        seed_durations_reshaped = seed_durations.reshape(1, length, 1)
        
        prediction_notes, prediction_durations = model.predict([seed_notes_reshaped, seed_durations_reshaped], verbose=0)
        
        # Convert predictions to probabilities
        prediction_notes = np.log(prediction_notes) / 1.0
        prediction_durations = np.log(prediction_durations) / 1.0
        
        exp_preds_notes = np.exp(prediction_notes)
        exp_preds_durations = np.exp(prediction_durations)
        
        prediction_notes = exp_preds_notes / np.sum(exp_preds_notes)
        prediction_durations = exp_preds_durations / np.sum(exp_preds_durations)
        
        index_note = np.argmax(prediction_notes)
        index_duration = np.argmax(prediction_durations)
        
        index_N_note = index_note / float(L_symb_notes)
        index_N_duration = index_duration / float(L_symb_durations)
        
        Notes_Generated.append(index_note)
        Durations_Generated.append(index_duration)
        
        Music_notes = [reverse_mapping_notes[char] for char in Notes_Generated]
        Music_durations = [reverse_mapping_durations[char] for char in Durations_Generated]
        
        Music = chords_n_notes(Music_notes, Music_durations)
        
        seed_notes = np.insert(seed_notes, len(seed_notes), index_N_note)
        seed_notes = seed_notes[1:]
        
        seed_durations = np.insert(seed_durations, len(seed_durations), index_N_duration)
        seed_durations = seed_durations[1:]
    
    Melody_midi = stream.Stream(Music)
    return Music_notes, Music_durations, Melody_midi


# Notes and durations created by the model
Music_notes, Music_durations, Melody = Melody_Generator(100)

# %%
cwd = os.getcwd()
filepath = cwd + "/drive/MyDrive/"
model.save(filepath + 'halsey_model.h5')

# %%
cwd = os.getcwd()
filepath = cwd + "/drive/MyDrive/"
Melody.write('midi',filepath + 'Melody_Generated_Halsey_1.mid')
# Out:
# '/content/drive/MyDrive/Melody_Generated_Halsey_1.mid'
